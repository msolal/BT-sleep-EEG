# %%
from mne_bids import BIDSPath, read_raw_bids

# %%
bids_root = '/storage/store2/data/mass-bids/SS3'

# %%
bids_path = BIDSPath(subject='030001', datatype='eeg', root=bids_root)

# %%
raw1 = read_raw_bids(bids_path=bids_path)
# Out:
# Extracting EDF parameters from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_events.tsv.
# Reading channel info from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_channels.tsv.

# %%
print(raw1.info['ch_names'])
# Out:
# ['ECG I', 'F8', 'O2', 'P3', 'C4', 'T5', 'Cz', 'P4', 'C3', 'A2', 'F7', 'Fp1', 'T6', 'F4', 'Fz', 'EOG Right Horiz', 'T4', 'F3', 'Oz', 'EMG Chin2', 'Fp2', 'Pz', 'O1', 'EOG Left Horiz', 'T3', 'EMG Chin1', 'EMG Chin3']

# %%
raw2 = read_raw_bids(bids_path=bids_path, extra_params=dict(exclude=['ECG I']))
# Out:
# Extracting EDF parameters from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_events.tsv.
# Reading channel info from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_channels.tsv.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ec97eb4b84ce> in <module>
# ----> 1 raw2 = read_raw_bids(bids_path=bids_path, extra_params=dict(exclude=['ECG I']))
#
# ~/mne-bids/mne_bids/read.py in read_raw_bids(bids_path, extra_params, verbose)
#     497                                             on_error='warn')
#     498     if channels_fname is not None:
# --> 499         raw = _handle_channels_reading(channels_fname, raw)
#     500
#     501     # Try to find an associated electrodes.tsv and coordsystem.json
#
# ~/mne-bids/mne_bids/read.py in _handle_channels_reading(channels_fname, raw)
#     391
#     392     # Set the channel types in the raw data according to channels.tsv
# --> 393     raw.set_channel_types(channel_type_dict)
#     394
#     395     # Set bad channels based on _channels.tsv sidecar
#
# <decorator-gen-33> in set_channel_types(self, mapping, verbose)
#
# ~/miniconda3/envs/mne/lib/python3.8/site-packages/mne/channels/channels.py in set_channel_types(self, mapping, verbose)
#     423         for ch_name, ch_type in mapping.items():
#     424             if ch_name not in ch_names:
# --> 425                 raise ValueError("This channel name (%s) doesn't exist in "
#     426                                  "info." % ch_name)
#     427
#
# ValueError: This channel name (EMG Chin3) doesn't exist in info.

# %%
raw3 = read_raw_bids(bids_path=bids_path, extra_params=dict(exclude=[]))
# Out:
# Extracting EDF parameters from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_events.tsv.
# Reading channel info from /storage/store2/data/mass-bids/SS3/sub-030001/eeg/sub-030001_channels.tsv.
